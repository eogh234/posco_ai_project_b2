# %%
import cv2
import pyrealsense2 as rs
import numpy as np

from realsense_depth import *

# %%
point = (400, 300)

def show_distance(event, x, y, args, params):
    global point
    point = (x, y)
    
# Initialize Camera Intel Realsense
dc = DepthCamera()

# Create mouse event
cv2.namedWindow('Color Frame')
cv2.setMouseCallback('Color Frame', show_distance)

while True:
    ret, depth_frame, color_frame = dc.get_frame()
    
    # Show distance for a specific point
    cv2.rectangle(color_frame, (110, 110), (400, 300), (0, 0, 255), 3)
    distance = depth_frame[point[1], point[0]]
    
    cv2.putText(color_frame, '{}mm'.format(distance), (point[0], point[1] - 20), cv2.FONT_HERSHEY_PLAIN, 2, (0,0,0), 2)
    
    cv2.imshow('Depth Frame', depth_frame)
    cv2.imshow('Color Frame', color_frame)
    key = cv2.waitKey(1)
    if key == 27:
        break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-fc179ae955d5> in <module>
#       6
#       7 # Initialize Camera Intel Realsense
# ----> 8 dc = DepthCamera()
#       9
#      10 # Create mouse event
#
# ~/바탕화면/YOLO_trial/realsense_depth.py in __init__(self)
#      20
#      21         # Start streaming
# ---> 22         self.pipeline.start(config)
#      23
#      24     def get_frame(self):
#
# RuntimeError: xioctl(VIDIOC_S_FMT) failed Last Error: 장치나 자원이 동작 중

# %%
## License: Apache 2.0. See LICENSE file in root directory.
## Copyright(c) 2015-2017 Intel Corporation. All Rights Reserved.

#####################################################
## librealsense tutorial #1 - Accessing depth data ##
#####################################################

# First import the library
import pyrealsense2 as rs

try:
    # Create a context object. This object owns the handles to all connected realsense devices
    pipeline = rs.pipeline()

    # Configure streams
    config = rs.config()
    config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)

    # Start streaming
    pipeline.start(config)

    while True:
        # This call waits until a new coherent set of frames is available on a device
        # Calls to get_frame_data(...) and get_frame_timestamp(...) on a device will return stable values until wait_for_frames(...) is called
        frames = pipeline.wait_for_frames()
        depth = frames.get_depth_frame().as_depth_frame()
        # 추가
        pixel_distance_in_meters = dpt_frame.get_distance(x, y)
        if not depth: continue

        # Print a simple text-based representation of the image, by breaking it into 10x20 pixel regions and approximating the coverage of pixels within one meter
        coverage = [0]*64
        for y in range(480):
            for x in range(640):
                dist = depth.get_distance(x, y)
                if 0 < dist and dist < 1:
                    coverage[x//10] += 1
            
            if y%20 is 19:
                line = ""
                for c in coverage:
                    line += " .:nhBXWW"[c//25]
                coverage = [0]*64
                print(line)
    exit(0)
#except rs.error as e:
#    # Method calls agaisnt librealsense objects may throw exceptions of type pylibrs.error
#    print("pylibrs.error was thrown when calling %s(%s):\n", % (e.get_failed_function(), e.get_failed_args()))
#    print("    %s\n", e.what())
#    exit(1)
except Exception as e:
    print(e)
    pass
# Out:
# <>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-2-ba8f46a6b43c>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y%20 is 19:
#                                               :X  .nhXWWWWWWWWWB
#                                               hW nWWWXXWWWWWWWWW
#                                             .:    nWWWXBWWWWWWWW
#                                              :     :hhhnXWWWWWWh
#                                                        ...:BWWWB
#                                                             .:hn
#                                                           .    .
#                                                              :.
#
#
#
#
#
#
#
#
#
#
#
#
#      nn
#    . .X:
#     :::W.
#       BWB
#                                               XW .: .Xh..
#                                               BX nWB nXWX.
#                                             :n     .
#                                             .:
#                                                           .h:.hB
#                                                          n::XWX.
#                                                           .XXh:
#
#
#
#
#
#
#
#
#
#
#
#
#
#      hn
#      hB:
#      :BW.
#       XWB
#                                               BW.:n.hWWWWWWWWWWW
#                                               BX.BWXBWWWWWWWWWWW
#                                                ..BWWWWWWWWWWWWWW
#                                             B:  BBBWWWWWWWWWWWWW
#                                             :. :WhBWXWWWWWWWWWWX
#                                                 :nnXXWWWWWWWWWWn
#                                                     XXWWWXXWWB:
#                                                      .  :nnh.
#                                                              .nh
#
#
#
#
#
#
#
#
#    .:
#
#                 .
#
#       n
#       h
#       BB:
#                                               BW: :.nWWWWWWWWWWW
#                                               BW.nWBhWWWWWWWWWWW
#                                                n.BWWWWWWWWWWWWWW
#                                             Bn .nBWWWWWWWWWWWWWW
#                                             Bn  WWhXWXWWWWWWWWWW
#                                                 nXnXWWWWWWWWWWWB
#                                                    nXWWWWWWWWWB.
#                                                     .nhWWWWX: .
#                                                            .n.:h
#                                                              ..
#
#
#
#
#
#
#
#      ..n
#       .        .:
#
#
#
#       ::
#       hX.
#                                               hWh   :BWWWWWWWWWW
#                                               BW.:WWBWWWWWWWWWWW
#                                                n.hWWXWWWWWWWWWWW
#                                             hB .:hXWWWWWWWWWWWWW
#                                             XB  hWhWXWWWWWWWWWWW
#                                                 nXnXWWWWWWWWWWWW
#                                                    .XWWWWWWWWWhh
#                                                    ...... nhn
#                                                            .:n:n
#                                                   .        ....
#
#
#
#
#
#
#
#      ..
#                .:
#                .
#
#      ..
#       n.
#       XB
#                                               BWn   .BWWWWWWWWWX
#                                               BW: BWBWWWWWWWWWWW
#                                                n.hWWXWWWWWWWWWWW
#                                             hX  nhWWWWWWWWWWWWWW
#                                             Xh  BXBWWXWWWWWWWWWW
#                                                 .BnnWWWWWWWWWWWW
#                                                    .XWWWWWWWWWBh
#                                                     ..hnhhXWB:
#                                                            .nhnh
#                                                   .        ....
#
#                ..
#                .
#
#
#       .n
#       XX:
#                                               hWn    XWWWWWWWWWW
#                                               XW..WWhWWWWWWWWWWW
#                                                : nWWWXWWWWWWWWWW
#                                             hW. nnXWWWWWWWWWWWWW
#                                             Bh  hWBWWXWWWWWWWWWW
#                                                 nXhBWWWWWWWWWWWW
#                                                     XWXXWWWWWWB:
#                                                    .::BXXBBWXn
#                                                             :nnn
#                                                   :         ...
#
#
#
#
#
#
#
#     :n::
#                ..
#
#
#      .B
#       n:
#       BB
#                                               nXh    XWWWWWWWWWW
#                                               WW: XWhWWWWWWWWWWW
#                                               .: hWWWWWWWWWWWWWW
#                                             BW. :hXWWWWWWWWWWWWW
#                                             XB  nWBWWWWWWWWWWWWW
#                                                 :WXBWWWWWWWWWWWW
#                                                    .WWWWWWWWWWX:
#                                                     :nhBXX::Bn
#                                                            .:nnn
#                                                            ....
#
#
#
#
#
#
#
#     :n
#
#
#
#      .n
#       B
#       XB
#                                               hWh    BWWWWWWWWWW
#                                               XW.:WWBWWWWWWWWWWW
#                                               .. :WWWXWWWWWWWWWW
#                                             hWn nhXWWWWWWWWWWWWW
#                                             XB  nWBWXWWWWWWWWWWW
#                                                 :XBBWWWWWWWWWWWW
#                                                     XWWWWWWWWWBn
#                                                    .:nhXXWWWX:
#                                                             .:nn
#                                                   :         .:.
#
#
#
#
#
#
#
#
#                 :
#
#
#       .
#       ..
#       hW.
#                                               XWh    hWWWWWWWWWW
#                                               WW::WWBWWWWWWWWWWW
#                                                ..:WWWXWWWWWWWWWW
#                                             hW: nnBWWWWWWWWWWWWW
#                                             XB  nWBWWXWWWWWWWWWW
#                                                 nXXhWWWWWWWWWWWW
#                                                     XWWWWWWWWWX:
#                                                    .:nhXXBBWXn
#                                                             .:nn
#                                                             .:.
#
#
#
#
#
#
#
#     n:
#                ..
#               ..
#
#       .
#       B
#       XX
#                                               WWh  . nWWWWWWWWWW
#                                               BWn:WWXWWWWWWWWWWW
#                                                ..:WWWXWWWWWWWWWW
#                                             hW: nhBWWWWWWWWWWWWW
#                                             XB  hWBWWXWWWWWWWWWW
#                                                 nXXhWWWWWWWWWWWW
#                                                     XWWWWWWWWWB:
#                                                     .nBXXhBXB:
#                                                             .:nn
#                                                   :         ...
#
#
#
#
#
#
#
#
#                .
#                .
#
#
#       B:
#       BX:
#                                               hWB  . :WWWWWWWWWW
#                                               BWh.WWBWWWWWWWWWWW
#                                              . ..:WWWXWWWWWWWWWW
#                                             hW: hBBWWWWWWWWWWWWW
#                                             hB  BWBWWXWWWWWWWWWW
#                                                 nXBhXXWWWWWWWWWW
#                                                     XWWWWWWWWWB:
#                                                      :hhXBnXB:
#                                                             .:nn
#                                                             ...
#
#
#
#
#
#      :
#                .:
#               ..
#
#       .
#       h:
#       BX.
#                                               BWB    nWWWWWWWWWW
#                                               XWh XWBXWWWWWWWWWW
#                                              . ...WWWXWWWWWWWWWW
#                                             BWn hXBWWWWWWWWWWWWW
#                                            .WX. hW:WWBWWWWWWWWWW
#                                                 :hnBXWWWWWWWWWWW
#                                                     XWWWWWWWWWBn
#                                                     ..nh:nXBhn
#                                                            .:n:h
#
#
#
#
#
#
#
#     .
#     .: .
#                .:
#                .
#
#
#       B.
#       BB
#                                               BWh    BWWWWWWWWWW
#                                               hW::WXhWWWWWWWWWWW
#                                              . :.nWWWWWWWWWWWWWW
#                                             BW: hXXWWWWWWWWWWWWW
#                                            .XX  XWBWWXWWWWWWWWWW
#                                                 .BnBXWWWWWWWWWWX
#                                                     hXWWWWWWWWB:
#                                                     ..::BBXXB.
#                                                             :::h
#                                                   .
#
#
#
#
#
#
#
#     .n:
#                .
#                .
#
#
#
#       hB
#                                               BWh    hWWWWWWWWWW
#                                               BW::WWBWWWWWWWWWWW
#                                              . n:nWWWWWWWWWWWWWW
#                                             XW: hXXWWWWWWWWWWWWW
#                                            :Xh  XWBWWXWWWWWWWWWW
#                                                 :hnhWWWWWWWWWWWX
#                                                     BXWWWWWWWWB:
#                                                      .nhBBXB:
#                                                             :::n
#
#
#
#
#
#
#
#
#     .:n.
#      .         .:
#                .
#
#
#       BB
#       BX.
#                                               BWh    hWWWWWWWWWW
#                                               BWn:WWhXWWWWWWWWWW
#                                              . :.:WWWXWWWWWWWWWW
#                                             BW: hBBWWWWWWWWWWWWW
#                                            .XX  XWBWWBWWWWWWWWWW
#                                                 :XhBXWWWWWWWWWWW
#                                                     BWWWWXXWWWX:
#                                                     ..nhnnBXB:
#                                                            .::nh
#
#
#
#
#
#
#
#
#       :
#      ..         :
#
#
#       n
#       Bn
#       BX:
#                                               BWh    nWWWWWWWWWW
#                                               BWn:WWBBWWWWWWWWWW
#                                              :.:.:WWWWWWWWWWWWWW
#                                             XWn hXBWWWWWWWWWWWWW
#                                            .XX. XWBWWBWWWWWWWWWW
#                                                 :XhBXWWWWWWWWWWW
#                                                     BWWWWWXXWWB:
#                                                      :nn::XXBn.
#                                                            .:nnh
#
#
#
#
#
#
#
#
#       :.
#       .        .:
#
#
#       n
#       h.
#       BB
#                                               BWh  . hWWWWWWWWWW
#                                               BWh.WWXXWWWWWWWWWW
#                                                :.:WWWWWWWWWWWWWW
#                                             BWn BXBWWWWWWWWWWWWW
#                                            :BX  WWBWWBWWWWWWWWWW
#                                                 nXBhXWWWWWWWWWWW
#                                                     XWWWWWWWWWh:
#                                                      .::: :BBn
#                                                             .::n
#
#
#
#
#
#
#
#
#     nn.
#                .:
#               :.
#
#
#       n
#       XW:
#                                               XWh  . nWXWWWWWWWW
#                                               hWh:WWXXWWWWWWWWWW
#                                              . :.:WWWXWWWWWWWWWW
#                                             BW: hhBWWWWWWWWWWWWW
#                                            :XX  XWBXWBWWWWWWWWWW
#                                                 :XXBXWWWWWWWWWWW
#                                                     XWWWWWWWWWh:
#                                                    ..:hBhhXWB:
#                                                            .::nh
#                                                   :          ..
#
#
#
#
#
#
#
#      :n
#                ..
#                .
#
#
#       X:
#       XX.
#                                               BWh  ..:WXWWWWWWWW
#                                               BWh.XWXXWWWWWWWWWW
#                                              ..:.:WWWWWWWWWWWWWW
#                                             BW: hBXWWWWWWWWWWWWW
#                                            .BX  XWBXWBWWWWWWWWWW
#                                                 :BXBXWWWWWWWWWWW
#                                                     XWWWWWWWWWh.
#                                                     .:hBBhBXBn
#                                                             n:nh
#                                                              ..
#
#
#
#
#
#
#
#
#                .:
#               :.
#
#       :
#       Xh
#       XW.
#                                               hWX   ..XBXWWWWWWX
#                                               WWX.XWXWWWWWWWWWWW
#                                              . .: WWWWWWWWWWWWWW
#                                             BWn hXBWWWWWWWWWWWWW
#                                            :WB  XWBXWhWWWWWWWWWW
#                                                 nXWhXWWWWWWWWWWW
#                                                     BWWWWWWWWWB:
#                                                      nhhhhBXB.
#                                                             hnnh
#                                                   :         ...
#
#
#
#
#
#
#
#      .n.
#                .:.
#               :.
#
#
#      .Bn
#       BX:
#                                               hWX    nWWWWWWWWWW
#                                               BWX XWBWWWWWWWWWWW
#                                              . .: WWWWWWWWWWWWWW
#                                             BWn nBXWWWWWWWWWWWWW
#                                            :XX:.BWBXWhWWWWWWWWWW
#                                                .:BWnXWWWWWWWWWWW
#                                                     XWWWWWWWWWXB
#                                                    ..:nXXBXWWn .
#                                                             .nhn
#                                                   .         ...
#
#
#
#
#
#
#
#     .:.
#                 :
#                .
#
#       n
#       Xn
#       hX.
#                                               nWW    :XWXWWWWWWX
#                                               nWX BWXXWWWWWWWWWW
#                                              . .. WWWWWWWWWWWWWW
#                                             hWh nBXWWWWWWWWWWWWW
#                                             BX. hWBBXWWWWWWWWWWW
#                                                  hXnXWWWWWWWWWWW
#                                                     XWWWWWWWWWWh
#                                                    :.:hWXhhBX:
#                                                              n::
#                                                   .         ...
#
#
#
#
#
#
#
#     :::.
#       .        .:
#                .
#
#
#       hh
#       hW
#                                               nWW    :XWWWWWWWWX
#                                               nWX XWXXWWWWWWWWWW
#                                              .... WWWWWWWWWWWWWW
#                                             hWh nBBWWWWWWWWWWWWW
#                                             Bn  nWBXWXWWWWWWWWWW
#                                                . hBnXWWWWWWWWWWW
#                                                     XWWWWWWWWWXn
#                                                    ..nhBhn::X: :
#                                                             .:::
#                                                   .         ...
#
#
#
#
#
#
#
#     nn
#                 :
#               ..
#
#       n
#       XB
#       XW
#                                               BWX   .nBBWWWWWWWW
#                                               BWX XWXXWWWWWWWWWW
#                                              . .. WWWWWWWWWWWWWW
#                                             hW: :hXWWWWWWWWWWWWW
#                                             BX. hWBXWhWWWWWWWWWW
#                                                 nBXhXWWWWWWWWWWW
#                                                     XWWWWWWWWWXh
#                                                    : .nBBBWXWn
#                                                             .nnn
#                                                   :         ...
#
#
#
#     .:::
#                .:
#
#
#       n
#       B:
#       Bh
#                                               BWB   .nXXWWWWWWWW
#                                               BWh.XWXBWWWWWWWWWW
#                                              . ...WWWWWWWWWWWWWX
#                                             BW: hhBWWWWWWWWWWWWW
#                                            .Xh  nWBXWBWWWWWWWWWW
#                                                 :XWhXWWWWWWWWWWW
#                                                     WWWWWWWWWWXn
#                                                    ..:nBBhBWWn
#                                                             .n::
#                                                   .         .:.
#
#
#
#
#
#
#
#     :n::
#                 .
#
#
#
#       :.
#       hX.
#                                               hWX   .nXXWWWWWWWW
#                                               BWX.WWXWWWWWWWWWWW
#                                              . ...WWWWWWWWWWWWWW
#                                             hWh :hBWWWWWWWWWWWWW
#                                             nn  nWBXWBWWWWWWWWWW
#                                                 :XXhWWWWWWWWWWWW
#                                                     XWWWWWWWWWWB
#                                                    .:nhWXX:BWn
#                                                    .        nnn:
#                                                   :         ::..
#
#
#
#
#
#
#
#     ..
#                .:.
#               ..
#
#       .
#       h
#       XX.
#                                               BWB   .:BBWWWWWWWX
#                                               BWX.XWXXWWWWWWWWWW
#                                                :..WWWWWWWWWWWWWW
#                                             hW: :hXWWWWWWWWWWWWW
#                                            :WB  nWBXWBWWWWWWWWWW
#                                                 :XWhWWWWWWWWWWWW
#                                                     WWWWWWWWWWWB
#                                                     :nnXXBBWXn
#                                                            .Bh::
#                                                   :        ::::.
#
#
#
#
#
#
#
#     .:.
#                .:
#                .
#
#       h
#       Xn
#       BW.
#                                               BWX   .nBBWWWWWWWX
#                                               hWX.XWXWWWWWWWWWWW
#                                                :..WWWXWWWWWWWWWW
#                                             hWn :hXWWWWWWWWWWWWW
#                                             XB  :WBXWXWWWWWWWWWW
#                                                 :XWhWWWWWWWWWWWW
#                                                     XWWWWWWWWWWX
#                                                     ::nBBhnWWn
#                                                              :::
#                                                   :         :::.
#
#
#
#
#
#
#
#     .n:
#                .
#                .
#
#
#       h:
#       WX:
#                                               BWX   .nBBWWWWWWWW
#                                               BWX XWXWWWWWWWWWWW
#                                                :: WWWWWWWWWWWWWW
#                                             BW: nhBWWWWWWWWWWWWW
#                                            .WB  nWBXWBWWWWWWWWWW
#                                                 nWWhWWWWWWWWWWWX
#                                                   . XWWWWWWWXWXX
#                                                     n:nXXXBWWh
#                                                         .   .nhn
#                                                   :        .:::.
#
#
#
#
#
#
#
#      :.
#                .n
#               ..
#
#
#       hh
#       XXn
#                                               hWB   .:XBXWWWWWWW
#                                               BWX XWXWWWWWWWWWWW
#                                                :: WWWXWWWWWWWWWW
#                                             hWn nhXWWWWWWWWWWWWW
#                                             Bn  hWBXWBWWWWWWWWWW
#                                                 .XWhWWWWWWWWWWWW
#                                                     BWWWWWWWXWWB
#                                                     .:nBB. hWn
#                                                              :::
#                                                   .        ::::.
#
#       ..
#      ..        .:
#                .
#
#
#       h
#       XX.
#                                               :WB    nXXXWWWWWWX
#                                               hWX BWXWWWWWWWWWWW
#                                                n:.WWWXWWWWWWWWWW
#                                             nWh nnBWWWWWWWWWWWWW
#                                             Wh  :WBXXBWWWWWWWWWW
#                                                 .BWnXWWWWWWWWWWW
#                                                     XWWWWWWWWWWn
#                                                     :nhWBhWWWh
#                                                         ..   :Bn
# ...
#                   nn       .  .           ::              B
#       .     .              :                             :.
#                        :.                    .
#                                                             .
#         XWWWWWWWWWWWWWWWWWWWWWWWWWWX:        nBWWWWWXhWWWWW:WWXB
#        .WWWWWWWBBWWWWWWWWWWWWWWWWWWWWWB: .hXWWWWWWWWXXWWWWWhXWWB
#         :WWWhnBn :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWXWXXWWWWWWWWXhWWW
#        .WWWB      BXXWWhn.  nWXWWBWWWWWWWWWXBXWWWWWWWWWWWWWWnhWW
#        .WWWWWWXhBXWWh      hWWWWWWWWWXhXXXWWWWWWWWWWWWWWXXn::.nn
#        :WWWWWWWWWWWWW:  :hWWWWWWhhBhn  WWWWWWXhXXWWWhn:  :BhhBhn
#        .WWWWWWWWWWWWWWWWWWWXh:..hnWWX  nWWWWWW.. .nn..:hWXWWXWWW
#        .WWWWWWWWWWWWWWBBWX.    .XXWXB   hhBh:.nhhhXBXWXWWWWnn.hB
#        hWWWWWWWWWWWh:XWWWWW. n.:WB        .BXWWXWXWWWXBhXXh.::XW
#        WWWWWWWWXh ..WWWWWWWWhXWWBn. .:hBBnhXXXBhXBBBhBnhXBXWXWWX
#        BXBn:.hWWW:  nWWWWWWWBB:  .XhXXBWXXWXXXXXWXWXBXWWWWWWWWWW
#               hXXh:.:XXXXnnn..    .XXWWBnXXhXBhXBBWWWWWWWXXXXXWW
#         .:nhXWWn  hWBBBh.nh:. .n  hX::h.BhBWWXWWWWWXh..BXBXWXnn:
#    :.nBXWWWWWh   nXXXBBXBWh    n..h: hBWWBBh:nhBnhBhhnnn:::
#     .B::BX:. :nnnXBXBXBhXWnnn.h: .nBXXWXB::hBXXB:BBXh
#         hXWBXBBXXBWWhXXXWnBh  .hBBhhXBBBnXXBBXB:
#         : :BBBnhXXBBBnhn..nh:hWWWXXBXXBBXhn      .:    nh
#      :.     nhnhBWBBBhBBBXWXBXWWXBhhBn:  ::  ..        :
#        ..   :nnXWhBWWWWWWWXXWXBhhh.               n
#           : .hXhnn:BXWXXWXXhnnn  ..                     h:
#              :n     nXBBn.   ::           :              .
#         :    h:      .                                   n.    .
#                                                      :
#             ..   nh                                       :n..
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.         nBXWWWWWhWWWWWnB
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB     .:hXWWWWWWWXXWWWWWn:
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWBhhXWWWWWWWXXXWWWWWWWWX:
#        WWWWWWWh::::nBhnBBhnhBXWWWWWWW::WWWWWWWWXWXWWWWWWWWWWWWWX
#        :WWWWWh      ..       nWWWWWXBXWWWWXXXXWWWWWWWWWWWWWWXBhh
#        nWWWWWXhh.     h     :WWWWWWWXhnn.hWWWWWXnXWWWWWXB: :  .
#        nWWWWWWWWW:     n :nXWWWWWB:nhXW. :WWWWWXn hhXB:.:h:hXXXB
#        XWWWWWWWWWWBnnBXWWWWWXhn  nWWWWWn  BXWWWB: .:.hWBBXBWXXWh
#        hWWWWWWWWWWWWWWXWXXXXB    .hXnnn     ..hhBBXXBWWXWXXBBhhh
#        :XWWWWWWWWWWWWn XWWWWW: .:hXW:    .nhhBBXXWXXXWWWBXBhBhnh
#        WWWWWWWWWWXX::.XWWWWWWXnWXBn  .nhBXXBXXBXXXBBhXXh.nWWWWWW
#       .WWWWXhn. BWWWh  nWWWWWWhh.   hBhXBXBBWBhXXXWWBhWXWWWWWWWX
#        Bn:      :XWn..:hXB::.:n. hnhhBXhWW:BXXXXBXWWWWWWXXXBXBh:
#    .:hnB:  .nBXWWh. :BXBnhhhXBh    .:BB:hn hhBBWXWWXBBh..:..h.
#    WWBnnhXWWWWXB:   nBXXhBBXXn.  ...  ..:BWB:.:: :nh:
#    .  B:XX.n:...hnnn::XXWhnBnnX..nh. hWWWXhhh.nBhn:.        .
#        .:nnhhXhBBnBXhBXhXhXh.n:  nBnnBBXXhnBXXXBh:
#         .BB: ::  nXhXnBBBn::nhBBBXXhBXBXBnhXWn:
#              .: nBBXBhXXWWhBBXXXXBn:h:n:         n.     :.
#          :.  :nXhhXXBXWWWWBBXWWXnn.                     n
#           .  .hWBWX::.:BWWWXhn                   ..h      .
#              BXXW:.:   nX:                            .  n
#         :     n:                       ..    .      .
#                    .                                      : .
#         XWWWWWWWWWWWWWWWWWWWWWWWWWWWXh:            :XWWBnWWWWWWn
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB         :XWWWWWWWhWWWWX.
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh   .nhXWWWWWWWWWXWWWWWWn
#       .WWWWWWWWWXXXXWWWWWWXWWWWWWWWWWWBn XWWWWWWWXXWWWWWWWWWWWWW
#        BWWWWWWB     nh:.    hWWWWWWXWnnhXWWWXXWXWWWWWWWWWWWWWWWX
#        nWWWWWWn       h     nWWWWWWXWWWWXBXWWWWWXWWWWWWWXWXBhn
#        :WWWWWWWWX.     .   :BWWWWWWBh::. .WWWWWWB BWWWWh:.  .nXB
#        BWWWWWWWWWX:   .nWWXWWWWBhn.:nWWX  nWWWXWW. . .nh::nXXWWW
#        XWWWWWWWWWWWWBXWWWWWXB.    XXWWXn   :hBn.:hhBBhBXBWXWBn:.
#        .WWWWWWWWWWWWWWXnBXXWW: :h :Wn    .: ..XhXWhWWWXWBXXXhhWW
#        nWWWWWWWWWWWBhn:BWWWWWBnhXWWBh:  .nBBhBXWWBXXhhXXBhhBXXXX
#       .WWWWWWWBhnXWWn  hWWWWWWXXBh. .hhBXhXWBWXBXXXXBXX:BhWWWWXX
#        WWXh:.    .WWX:  nWXXXX:B.   hBBWXXX:BB:XXXXXBXWWWWWWBXXX
#        :n.    :nBWX. :WWBBn::  .:n nhBB..n:nBhhXWXXWWXXXXXh::Xh
#    hXWWBnnhBWWWWW:  .BXBBBh:n    .:  nn hh::BXXB:nXWn: n: :.
#    hh..hXWBhXBh.   nhhn.nB::: :: .  :h.:hhBB::. :hBXn  .
#       .n:h..nnhhhBh.  hhhBBX.nn   ::hhBBWWXXhBBh:X:
#        h hXXhh::n::.nhhnBhXn   : ..:nXWBB:.nnhhh:
#                   .n: nBhhhhBXnnhBBBBB.::..     .    .  :
#            .nn:hBnhXh:WWXXhBWXXXBXnhn            :  :.
#          .  :nhn:XWWXXXXWXWXXXBnn..:        .     ::     n
#          .   nBhhhn   .hXXBh:                         : ..
#          ..  hX.:      :n                      :        .
#               .nn ..                              .      :. h.
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWWhn             BWWhhWWWWWWXn
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.         :XWWWWWBXWWWWXhX
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh     .hXWWWWWWWXXWWWWWWnW
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh.:XBWWWWWWXXWWWWWWWWWWWX
#        BWWWWWWn    .hB.:.  .nWWWWWWWX:nBWWWWXXXWWWWWWWWWWWWWWWWW
#        :WWWWWW:      h.     hWWWWWWWWWWXXXWWWWWXXWWWWWWXWXBhh.
#        :WWWWWWWW:     .    nWWWWWWXBn:: .hWWWWWB BWWWWB:    .B:
#        BWWWWWWWWWB:. :hXhXWWWWWBhnhhWWW  .WWWBXWn : :nn.nhhWXXWB
#        hWWWWWWWWWWWWWWWWXXWWh.   hWWWWX.  hBBB:..BBBBBnBWWWXBnn.
#         XWWWWWWWWWWWWX:nBWWWX .n  BX        :hBXBBWXXWWWXXWWWWn
#        XWWWWWWWWWWBn::BWWWWWWXnBXWXB:.  .BXBXXBXBBWBBBBXhhhXhXWX
#       .WWWWWWXBnXWWn. hWWWWWWBBhn.  nhBXhBXXWhhBBBBXWXXWWWWXWWWW
#        WWBn.     XWX:  nWWXXB:. :: nnXWXhn.BB:BBXBBXWWWXWWWWXhBh
#       .h.    .nhXWn .BWXBnn:h n:n.hhBn.:h.nXBBBhBWWWWWWXXhhh:
#    BWWWhn:nXWWWWn  .BXhhXBhX. ..    .  nhBBWhBhnWWXn. .:
#    Bn.nBXBBXXn.:  :hhB:n:hBX::n:.:    .hBWX:h :nhBhn
#       ..B  hhhBBBXh:BnnBhBXhBB. nnhnBhhBWBhBWBX:.
#        ::nBhn:.nnn .hnhhnh:     nBnhhXXhh. :. :       ..
#            :.   n.:nnhBh.XBXBn:hBXnnhnn::        n
#             n:.hnBWh:BWWXn:n:nXXXXBn             h      .
#             nBh.BWWXXBWX::nBBhh:.                 :n
#           :..WWX      XXWB::                             :   .
#              .:       n.      :
#                                                           :
#         nWWWWWWWWWWWWWWWWWWWWWWWWWWWW:            .BXWnWWWWWBBn
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWX           :XWWWBnWWWWWnX:
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.      .nXWWWWWWWXWWWWWBBW
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWn  .nBWWWWWWBXWWWWWWWWWWnW
#       .WWWWWWWhnnnnnhXWWWWWhBWWWWWWWW:.nBWWWWXXWXXWWWWWWWWWWWWWh
#        hWWWWWB        nnBBhBXWXWWWWWWWWWWXXXXWXWWWWWWWWXWWWWXh::
#        hWWWWWWXX:          :WWWWWWWWBn...WWWWWWhhWWWWWWhn.  ..
#        XWWWWWWWWWX      .WBXWWWWXn .BXn  WWWWXWW .nnnnh...hhXXh:
#        BWWWWWWWWWWXhnhWWWWXXn:.  hWWWWW   nXWBBn.:n.nXhXWWXWhXhh
#        .WWWWWWWWWWWWWWXBXhXWh .: .Bh:.      .nhXBBXhWXXWBBBB:Bh
#    :   nXWWWWWWWWWWBBnhWWWWWWh :hXWWn    hB:hXBWXBhXBXXWhBXnBWXB
#        WWWWWWWWXWWX.  WWWWWWWWBBBh  :nhBhBhXWhBXBXXXWBBhBWWWWWXX
#        WWXBh:   :WWWn  hWWWWWhh .  hhhXBBBXXhhBXXWWXXXWWWWWWXXWX
#        :.      :hXh: hBBXn  nhBn:  :.n:nhnBXBnBBhXWWWWWXWh:nBXn
#    nBXXB: :hBWWWh. .BBnhXXBh:  .n:     ::n..hXBBWWXBn.::h.::
#    Xh:nBWWWWWhn:  .:Bhnn hWn::  :: .:  :nhBXBhh:nhn.
#       .:B :h::nBnhhnBnnWnhBhBB  :   : XXnBBBBBBn
#        .nBBBBnhn.B.nhhnnhBnh:. .h    BXXhhnhBB:
#          ..   n :....n.nnBhBXB:.. :hnBXh:.              ..
#             : .hhBXhXWXBBhh:::BnhXXh..          .h     ::
#             .nh.:WWXXBh: .nhhBXBn.                 .    .
#           .  h:n ::   nBWBh.hB.                    . .:
#        .     n.     ..:      :         .            :n
#                                                           . .
#        .BWWWWWWWWWWWWWWWWWWWWWWWWWWWWh            BXBXWWWWhhWWWW
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWh            hWWhWWWWWXXhhh
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh         .:XWWWWhWWWWWnWWB
#        :XWWWWWWWWWWWWWWWWWWWWWWWWWWWWX      nhXWWWWWWXBWWWWWXhWX
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB   nXWWWWWXXBXWWWWWWWWWhXW
#        BWWWWWX       nBXWWB.:WWWWWWWXnhXWWWXXXhWWWWWWWWWWWWWWW:X
#        nWWWWWX::        :::XXXWWWWWWWWXBXBXWWWhWWWWWWWBWWXBh.
#        XWWWWWWWWWB:     :n:BWWWWWXnnnn. hWWWWWB.nWWWWW:.    ::.
#        WWWWWWWWWWWWBhnnBWWWWWWhn.:hXWWB  XWWXWWn   :h:.::XWWXBBh
#        BWWWWWWWWWWWWWWWWWBXX.    XXXXXh  .:hhn:nhhBBXBXXWWWXB
#        nWWWWWWWWWWWWW:nXWWWWB   nWWh      .nhXXhBWXXWWWWXBBXXn:n
#        WWWWWWWWWWWn  hWWWWWWWhBWWXhn: :.:BhBXXXBBBXnBWXXBhXWWXXB
#        WWWWWh:::XWWh  hWWWWWWWX.   hhBXhWBnBBBXXXXXXXBXBBWXXWWWX
#        hn.      nWhh.::BWXhhhBn   :hBXBXBnXBXBhhXXXWXWWWWWXBXXXh
#    .:nn.   .nBXWXh  :Xhhh.  n:.nn: nn.BXnBBhBnhWWWXWXBh.:BXBn:.
#    XWBn:hhWWWWWn   nBBhnBnB:   nB.    hnh:nWWn. :hnn:.:: ..  .
#      :hBhnBB: .n:hhhB:hBhhBhBh nh   .:hXWWB..:nh:.
#        :::XXXXBXXh hBhBXhXnBB   .nnhhBXBXXXXhhB:
#       ..:h:..n:nn:nhhh.nXh::nnBXnhXXBhBhhhh:
#          nn ..:h:::nX:::hBXh. :hBhnn:::      :  .n.    :.
#             .:nBWXnnhXBhn..:hBBXhn.                      :
#             .:.BWXBhn:  nXXB:n:              .           n
#      :.   . .hh    nnhhBh:         n      .                   :
#                  .    . .                                   .
#         hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW:       nXWWhWWWWXBWWWWWW
#        .XWWWWWWWWWWWWWWWWWWWWWWWWWWWWh.          :XWBXWWWWhXWWWW
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh           nWWWnXWWWWXhXWW
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB       :hBWWWWWXXWWWWXhWWX
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW  ::hXWWWWWWWXWXWWWWWWhXWW
#       .WWWWWWWhhhnn .BXWWWXXXWWWWWWWn .nWWWWWWXXXXWWWWWWWWWWWhXW
#        hWWWWWW  .nBBXWWWWWB .WWWWBXBBWWWXXBWWXBWWWWWWWXWWWWXBhnB
#        hWWWWWWWWWWWWWWWXWWWWWWWWWWWXhn:.WWWWWWnnWWWWWWXXh:.   n
#        BWWWWWWWWWWWWWWWWWWWWWWWXh..:XW. hWWWWXX:nhhnnnh.:nhBXXBn
#        BWWWWWWWWWWWWWWWWWWWBn:   WWWWWh  nXWWBh:.::nWBBXXWWWXnh.
#        :WWWWWWWWWWWWWhnhBXWW. n  BB::n  .   :hBBBWBWWXWWBBnnn :n
#        nWWWWWWWWWWBhnhBWWWWWX :hXWWB:   nh:hhhBWXWWXXXXBB:XWXBWX
#       .WWWWWWWBBWWh  hWWWWWWWXBhn. .:nBBXBWWBBXXXBBXBXBBXWWWXXWX
#        WWBn:    hWWW  .XWWWWXXn.  hBnXWXXhXBhXXXXXWXBWWWWWWWWWWW
#              .:BXB .nWXXhn.:nhh: :. :nnn :XhBnnBWWWWWWWWXBBXBBn.
#   .XWWBn..hXWWWh. .BBhhXWnBnn    : h. :nn:.hWXhXWWXh:hB::hh.  ..
#    ::nBWWWWWXhn  .nhXB:nBWXnhh..: :hhnhhXXBn...n:....:
#        n .h::nhhh:: .hWXBXhhX:  . :.nBBWXBB.n:XBn
#         :BBBhhnhB:.BhhBBXh:n: .:hnnBBhWBXB:Bnh:          :
#        n.:n   .  .hnnBhh..:hBWBnhXBhBBBBn.n:    ..   . :
#          .   . .nn hhhXXXWWn hBBXB. .           :.       .
#             nhn:hnhXWXn: :nhWWhhn                    :. n
#              :BXBh:..nhXWXBn:.
#              ..: .BhBBn.                                 n
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW:      nBWWBWWWWXnXWWWWX
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWn.         XWWBWWWWWBBWWWW
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWW:            WWXBWWWWWX:XWW
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB        :hXWWWWBBWWWWBhWWB
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB.  .hXWWWWWWWWXWWWWWWhWWW
#       nWWWWWWWWBXBhnhWWWWWWWWWWWWWWWXBBWWWWWWWWWWXWWWWWWWWWWWhWW
#        BWWWWWWh  .nnhXWWWWW  BWWWWXBBWWWWWWWXXXWWWWWWWWWWWWWXhnX
#        :WWWWWWWBWWWWWWWWWWWBBWWWWWWWXBhnXWWWWW.BWWWWWWXWB:::
#        BWWWWWWWWWWWWWWWWWWWWWWWWXn.nBX. nWWWWXX::BXBh:n..:nh::..
#        BWWWWWWWWWWWWWWWWWWWWBh.  WWWWWn  BWWWWB.  .nXBWBBWWWXWBh
#        :WWWWWWWWWWWWWXXXXWWX  .  BBnnh.   .:.nhXXXnBXWXXWX:hh..
#    ..  :hWWWWWWWWWWWXnBWWWWWX .nhWWX:   .n .XBBhXXXWWXXBXhhXh:nh
#        WWWWWWWWXWWh  hWWWWWWWXWXBn. .:hhBBXWXBXXWXhBBBXXhXXWWWWW
#        WWWBh:   XWWX  nWWWWWWXn : .X:BhBWBBWXXWXXXXWXXWWWWWWWWWB
#        .      .nXX:..BXXB:n:   n. hBh:hB:XXBXXWWWWXWWWXWWWXXXXXB
#    nXWXh..nhXWWXn. hWh:BWBh::h ::nhh. :. :hhXXXWBBXBBBXBhWB::
#    hnnhXWWWWWBB.  .hXXBBhBXhBn n:       BXXn:h:. ....:
#      .nB..Bn::nhnnh:hBB.BXBnB:.Xh  nBXXWXWBn:nhXh.
#          hBXBhhXWn.XXhBBXh n:  hB::BXBWXBBXhhXn.
#         ..   : nXhXnnn:Bn  nhXBhXBnhBBXBh:hBn   .      .
#       .:      hn:BnhXBnnhBBXXBWXXhnn::.        ...:
#         .n. :. hXnhWWXBhhh.nXWWBhh
#             ..BBXBn.  :nBXWBn.   .                 :.     .
#          n   nn     :BWWBhB.                           . .
#         BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWn ..   nXXnWWWWh:hXWWWW
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWXn      .nBWWXWWWWWXXWWWWW
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh           nWWnWWWWWBXhXWW
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB        .:hXWWWnXWWWWhXWWX
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWn:   nhXWWWWWWXXXWWWWXhWWW
#       nWWWWWWWWWWWB::XWWWWWWWWWWWWWWWWWWWWWWWWWWXXXXWWWWWWWWhXWW
#        XWWWWWWh   . .hWWWWW::BWWWBhhBWWWWWWXXXWWWWWWWWWWWWWWWhWW
#        .WWWWWWXBXWWWWWWWWWWhnBWWWWWWWWBhXXWWWW:XWWWWWXXWXXB..  .
#        hWWWWWWWWWWWWWWWWWWWWWWWWWh:nhB  BWWWWWB.WWWWWB:n ..:nhn.
#        XWWWWWWWWWWWWWWWWWWWWWBn. BXWWWh  XWXWWX:  .nh:BXBWWXWBXX
#        nWWWWWWWWWWWWWWXWXWXB.    BXBBB.  :nnn:nhBXBXBBXWXBBnhnh:
#        hWWWWWWWWWWWWB:hWWWWWn  .nXWh.   .. .BXWBWWWWWWWXXXWX:.nh
#        WWWWWWWWXWXn nBWWWWWWWhWWXh:. .nhXBBXXBXXXBBBXXB.:BBXWXXX
#        WWWXBh: :WWWB  hWWWWWWWX   nX:hBXXXXXXXBXBBWW:hWWWWWWWWXX
#        n:      :BWhn.nnXXBBh.n.h .BXXWXXhXXBhhBXBWWWWWWWWXWXWWXX
#    :hBBn  :nBWWXn. .XXhhBhhWBX:: ::nnhB::hBXXnhWXhWXXXB.:XBnn:
#    XhnhBXWWWWXB   :XXhBhhBXh . :h .B:nh::nhXBB.   n:  . :
#      :BX::Wh: :n:hXn..nnhWXnB: :  n:nWXWBBhhBBn::hhh
#        . nhXXWWXBBhX:BX:hh.hB. :nh:hBWBhBh.BXhh:
#       . .h:. :.. :BhhBBXB. .:hhXXBXXB.BhB:hh           . .n
#            . .nhhBXBXn:BXXXBBhhBXB :hh:.                  n
#          Bn :. nWX:WXXBBWWXXWXWBBh               .  .
#             nnBWWWXnn..nWXXhhn.       .                  .
#             .hhh:   .BXhnBX.                          .n:n     :
#         hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW:     .nWWnWWWWW:BXWWWW
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB:       :.XWXBWWWWWXWWWWW
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWh           .WWBXWWWWXXnhWW
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX        ..hWWWWXhWWWWBBWWX
#       :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWBn   nBWWWWWWWXXXWWWWWnWWW
#       nWWWWWWWWWWWXnhXWWWWWWWWWWWWWWWWWWWWWWWWWWXXXWWWWWWWWWWhWW
#        hWWWWWWW:  : .hXWWWW:.hWWWXBWWWWWWWWWWXXWWWWWWWWWWWWWWBBW
#        .XWWWWWWBWWWWWWWWWWWh:hWWWWWWWXXhXWWWWW.BWWWWWWBWXXB... .
#        BWWWWWWWWWWWWWWWWWWWWWWWWWh::hX. hWWWWWB.nXWWXn:.   :nnnn
#        XWWWWWWWWWWWWWWWWWWWWXBn. hXWWWh  BWWWWXn ..hhBBBBWWWWXBh
#        BWWWWWWWWWWWWWWXXWWXB:.n  nXhBB:  .:n::nhBXBXBBWWXhB:nnBn
#        nWWWWWWWWWWWWX:nWWWWWB  .nXWB:    .. BXWXXWWWWWXXBWWWh:nn
#        WWWWWWWWXXWh  nWWWWWWWhWWXh:: .hhXXhXWXWBXBhBhXWhBXnXWWWW
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ba8f46a6b43c> in <module>
#      40                     line += " .:nhBXWW"[c//25]
#      41                 coverage = [0]*64
# ---> 42                 print(line)
#      43     exit(0)
#      44 #except rs.error as e:
#
# ~/anaconda3/envs/AIBD/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# KeyboardInterrupt:

# %%
###############################################
##      Open CV and Numpy integration        ##
###############################################

import pyrealsense2 as rs
import numpy as np
import cv2

# Configure depth and color streams
pipeline = rs.pipeline()
config = rs.config()

# Get device product line for setting a supporting resolution
pipeline_wrapper = rs.pipeline_wrapper(pipeline)
pipeline_profile = config.resolve(pipeline_wrapper)
device = pipeline_profile.get_device()
device_product_line = str(device.get_info(rs.camera_info.product_line))

found_rgb = False
for s in device.sensors:
    if s.get_info(rs.camera_info.name) == 'RGB Camera':
        found_rgb = True
        break
if not found_rgb:
    print("The demo requires Depth camera with Color sensor")
    exit(0)

config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)

if device_product_line == 'L500':
    config.enable_stream(rs.stream.color, 960, 540, rs.format.bgr8, 30)
else:
    config.enable_stream(rs.stream.color, 640, 480, rs.format.bgr8, 30)

# Start streaming
pipeline.start(config)

try:
    while True:

        # Wait for a coherent pair of frames: depth and color
        frames = pipeline.wait_for_frames()
        depth_frame = frames.get_depth_frame()
        color_frame = frames.get_color_frame()
        if not depth_frame or not color_frame:
            continue

        # Convert images to numpy arrays
        depth_image = np.asanyarray(depth_frame.get_data())
        color_image = np.asanyarray(color_frame.get_data())

        # Apply colormap on depth image (image must be converted to 8-bit per pixel first)
        depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET)

        depth_colormap_dim = depth_colormap.shape
        color_colormap_dim = color_image.shape

        # If depth and color resolutions are different, resize color image to match depth image for display
        if depth_colormap_dim != color_colormap_dim:
            resized_color_image = cv2.resize(color_image, dsize=(depth_colormap_dim[1], depth_colormap_dim[0]), interpolation=cv2.INTER_AREA)
            images = np.hstack((resized_color_image, depth_colormap))
        else:
            images = np.hstack((color_image, depth_colormap))

        # Show images
        cv2.namedWindow('RealSense', cv2.WINDOW_AUTOSIZE)
        cv2.imshow('RealSense', images)
        cv2.waitKey(1)

finally:

    # Stop streaming
    pipeline.stop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f1e01b2334db> in <module>
#      40
#      41         # Wait for a coherent pair of frames: depth and color
# ---> 42         frames = pipeline.wait_for_frames()
#      43         depth_frame = frames.get_depth_frame()
#      44         color_frame = frames.get_color_frame()
#
# KeyboardInterrupt:

# %%
import pyrealsense2 as rs
import numpy as np

# %%
# Configure depth and color streams
pipeline = rs.pipeline()
config = rs.config()

# Get device product line for setting a supporting resolution
pipeline_wrapper = rs.pipeline_wrapper(pipeline)
pipeline_profile = config.resolve(pipeline_wrapper)
device = pipeline_profile.get_device()
device_product_line = str(device.get_info(rs.camera_info.product_line))

found_rgb = False

for s in device.sensors:
    if s.get_info(rs.camera_info.name) == 'RGB Camera':
        found_rgb = True
        break
if not found_rgb:
    print("The demo requires Depth camera with Color sensor")
    exit(0)

config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)

if device_product_line == 'L500':
    config.enable_stream(rs.stream.color, 960, 540, rs.format.bgr8, 30)
else:
    config.enable_stream(rs.stream.color, 640, 480, rs.format.bgr8, 30)

# Start streaming
pipeline.start(config)

try:
    while True:
        pc = rs.pointcloud()
        points = rs.points
        frames = pipeline.wait_for_frames()
        depth = frames.get_depth_frame()
        color = frames.get_color_frame()
        pc.map_to(color)
        points = pc.calculate(depth)
        color_img = np.asanyarray(color.get_data())
        depth_img = np.asanyarray(depth.get_data())
        vtx = np.asanyarray(points.get_vertices())
        tex = np.asanyarray(points.get_texture_coordinates())
        pt_vtx = np.zeros( (len(vtx), 3) , float )
        for i in range(len(vtx)):
             pt_vtx[i][0] = np.float(vtx[i][0])
             pt_vtx[i][1] = np.float(vtx[i][1])
             pt_vtx[i][2] = np.float(vtx[i][2])

    # If depth and color resolutions are different, resize color image to match depth image for display
    if depth_colormap_dim != color_colormap_dim:
        resized_color_image = cv2.resize(color_image, dsize=(depth_colormap_dim[1], depth_colormap_dim[0]), interpolation=cv2.INTER_AREA)
        images = np.hstack((resized_color_image, depth_colormap))
    else:
        images = np.hstack((color_image, depth_colormap))

    # Show images
    cv2.namedWindow('RealSense', cv2.WINDOW_AUTOSIZE)
    cv2.imshow('RealSense', images)
    cv2.waitKey(1)

finally:

    # Stop streaming
    pipeline.stop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-345b76b2e64e> in <module>
#      46              pt_vtx[i][0] = np.float(vtx[i][0])
#      47              pt_vtx[i][1] = np.float(vtx[i][1])
# ---> 48              pt_vtx[i][2] = np.float(vtx[i][2])
#      49
#      50     # If depth and color resolutions are different, resize color image to match depth image for display
#
# KeyboardInterrupt:

# %%
####################################################
##              Align Depth to Color               ##
#####################################################

# First import the library
import pyrealsense2 as rs
# Import Numpy for easy array manipulation
import numpy as np
# Import OpenCV for easy image rendering
import cv2

# Create a pipeline
pipeline = rs.pipeline()

# Create a config and configure the pipeline to stream
#  different resolutions of color and depth streams
config = rs.config()

# Get device product line for setting a supporting resolution
pipeline_wrapper = rs.pipeline_wrapper(pipeline)
pipeline_profile = config.resolve(pipeline_wrapper)
device = pipeline_profile.get_device()
device_product_line = str(device.get_info(rs.camera_info.product_line))

found_rgb = False
for s in device.sensors:
    if s.get_info(rs.camera_info.name) == 'RGB Camera':
        found_rgb = True
        break
if not found_rgb:
    print("The demo requires Depth camera with Color sensor")
    exit(0)

config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)

if device_product_line == 'L500':
    config.enable_stream(rs.stream.color, 960, 540, rs.format.bgr8, 30)
else:
    config.enable_stream(rs.stream.color, 640, 480, rs.format.bgr8, 30)

# Start streaming
profile = pipeline.start(config)

# Getting the depth sensor's depth scale (see rs-align example for explanation)
depth_sensor = profile.get_device().first_depth_sensor()
depth_scale = depth_sensor.get_depth_scale()
print("Depth Scale is: " , depth_scale)

# We will be removing the background of objects more than
#  clipping_distance_in_meters meters away
clipping_distance_in_meters = 1 #1 meter
clipping_distance = clipping_distance_in_meters / depth_scale

# Create an align object
# rs.align allows us to perform alignment of depth frames to others frames
# The "align_to" is the stream type to which we plan to align depth frames.
align_to = rs.stream.color
align = rs.align(align_to)

# Streaming loop
try:
    while True:
        # Get frameset of color and depth
        frames = pipeline.wait_for_frames()
        # frames.get_depth_frame() is a 640x360 depth image

        # Align the depth frame to color frame
        aligned_frames = align.process(frames)

        # Get aligned frames
        aligned_depth_frame = aligned_frames.get_depth_frame() # aligned_depth_frame is a 640x480 depth image
        color_frame = aligned_frames.get_color_frame()

        # Validate that both frames are valid
        if not aligned_depth_frame or not color_frame:
            continue

        depth_image = np.asanyarray(aligned_depth_frame.get_data())
        color_image = np.asanyarray(color_frame.get_data())

        # Remove background - Set pixels further than clipping_distance to grey
        grey_color = 153
        depth_image_3d = np.dstack((depth_image,depth_image,depth_image)) #depth image is 1 channel, color is 3 channels
        bg_removed = np.where((depth_image_3d > clipping_distance) | (depth_image_3d <= 0), grey_color, color_image)

        # Render images:
        #   depth align to color on left
        #   depth on right
        depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET)
        images = np.hstack((bg_removed, depth_colormap))

        cv2.namedWindow('Align Example', cv2.WINDOW_NORMAL)
        cv2.imshow('Align Example', images)
        key = cv2.waitKey(1)
        # Press esc or 'q' to close the image window
        if key & 0xFF == ord('q') or key == 27:
            cv2.destroyAllWindows()
            break
finally:
    pipeline.stop()

# %%
#####################################################
##          rs400 advanced mode tutorial           ##
#####################################################

# First import the library
import pyrealsense2 as rs
import time
import json

DS5_product_ids = ["0AD1", "0AD2", "0AD3", "0AD4", "0AD5", "0AF6", "0AFE", "0AFF", "0B00", "0B01", "0B03", "0B07", "0B3A", "0B5C"]

def find_device_that_supports_advanced_mode() :
    ctx = rs.context()
    ds5_dev = rs.device()
    devices = ctx.query_devices();
    for dev in devices:
        if dev.supports(rs.camera_info.product_id) and str(dev.get_info(rs.camera_info.product_id)) in DS5_product_ids:
            if dev.supports(rs.camera_info.name):
                print("Found device that supports advanced mode:", dev.get_info(rs.camera_info.name))
            return dev
    raise Exception("No D400 product line device that supports advanced mode was found")

try:
    dev = find_device_that_supports_advanced_mode()
    advnc_mode = rs.rs400_advanced_mode(dev)
    print("Advanced mode is", "enabled" if advnc_mode.is_enabled() else "disabled")

    # Loop until we successfully enable advanced mode
    while not advnc_mode.is_enabled():
        print("Trying to enable advanced mode...")
        advnc_mode.toggle_advanced_mode(True)
        # At this point the device will disconnect and re-connect.
        print("Sleeping for 5 seconds...")
        time.sleep(5)
        # The 'dev' object will become invalid and we need to initialize it again
        dev = find_device_that_supports_advanced_mode()
        advnc_mode = rs.rs400_advanced_mode(dev)
        print("Advanced mode is", "enabled" if advnc_mode.is_enabled() else "disabled")

    # Get each control's current value
    print("Depth Control: \n", advnc_mode.get_depth_control())
    print("RSM: \n", advnc_mode.get_rsm())
    print("RAU Support Vector Control: \n", advnc_mode.get_rau_support_vector_control())
    print("Color Control: \n", advnc_mode.get_color_control())
    print("RAU Thresholds Control: \n", advnc_mode.get_rau_thresholds_control())
    print("SLO Color Thresholds Control: \n", advnc_mode.get_slo_color_thresholds_control())
    print("SLO Penalty Control: \n", advnc_mode.get_slo_penalty_control())
    print("HDAD: \n", advnc_mode.get_hdad())
    print("Color Correction: \n", advnc_mode.get_color_correction())
    print("Depth Table: \n", advnc_mode.get_depth_table())
    print("Auto Exposure Control: \n", advnc_mode.get_ae_control())
    print("Census: \n", advnc_mode.get_census())

    #To get the minimum and maximum value of each control use the mode value:
    query_min_values_mode = 1
    query_max_values_mode = 2
    current_std_depth_control_group = advnc_mode.get_depth_control()
    min_std_depth_control_group = advnc_mode.get_depth_control(query_min_values_mode)
    max_std_depth_control_group = advnc_mode.get_depth_control(query_max_values_mode)
    print("Depth Control Min Values: \n ", min_std_depth_control_group)
    print("Depth Control Max Values: \n ", max_std_depth_control_group)

    # Set some control with a new (median) value
    current_std_depth_control_group.scoreThreshA = int((max_std_depth_control_group.scoreThreshA - min_std_depth_control_group.scoreThreshA) / 2)
    advnc_mode.set_depth_control(current_std_depth_control_group)
    print("After Setting new value, Depth Control: \n", advnc_mode.get_depth_control())

    # Serialize all controls to a Json string
    serialized_string = advnc_mode.serialize_json()
    print("Controls as JSON: \n", serialized_string)
    as_json_object = json.loads(serialized_string)

    # We can also load controls from a json string
    # For Python 2, the values in 'as_json_object' dict need to be converted from unicode object to utf-8
    if type(next(iter(as_json_object))) != str:
        as_json_object = {k.encode('utf-8'): v.encode("utf-8") for k, v in as_json_object.items()}
    # The C++ JSON parser requires double-quotes for the json object so we need
    # to replace the single quote of the pythonic json to double-quotes
    json_string = str(as_json_object).replace("'", '\"')
    advnc_mode.load_json(json_string)

except Exception as e:
    print(e)
    pass
# Out:
# Found device that supports advanced mode: Intel RealSense D435I
# Advanced mode is enabled
# Depth Control:
#  minusDecrement: 10, deepSeaMedianThreshold: 500, scoreThreshA: 1, scoreThreshB: 2047, textureDifferenceThreshold: 0, textureCountThreshold: 0, deepSeaSecondPeakThreshold: 325, deepSeaNeighborThreshold: 7, lrAgreeThreshold: 24
# RSM:
#  rsmBypass: 0, diffThresh: 4, sloRauDiffThresh: 1, removeThresh: 63
# RAU Support Vector Control:
#  minWest: 1, minEast: 1, minWEsum: 3, minNorth: 1, minSouth: 1, minNSsum: 3, uShrink: 3, vShrink: 1
# Color Control:
#  disableSADColor: 0, disableRAUColor: 0, disableSLORightColor: 0, disableSLOLeftColor: 0, disableSADNormalize: 0
# RAU Thresholds Control:
#  rauDiffThresholdRed: 51, rauDiffThresholdGreen: 51, rauDiffThresholdBlue: 51
# SLO Color Thresholds Control:
#  diffThresholdRed: 72, diffThresholdGreen: 72, diffThresholdBlue: 72
# SLO Penalty Control:
#  sloK1Penalty: 60, sloK2Penalty: 342, sloK1PenaltyMod1: 105, sloK2PenaltyMod1: 190, sloK1PenaltyMod2: 70, sloK2PenaltyMod2: 130
# HDAD:
#  lambdaCensus: 26, lambdaAD: 800, ignoreSAD: 0
# Color Correction:
#  colorCorrection1: 0.298828, colorCorrection2: 0.293945, colorCorrection3: 0.293945, colorCorrection4: 0.114258, colorCorrection5: -0, colorCorrection6: -0, colorCorrection7: -0, colorCorrection8: -0, colorCorrection9: -0, colorCorrection10: -0, colorCorrection11: -0, colorCorrection12: -0
# Depth Table:
#  depthUnits: 1000, depthClampMin: 0, depthClampMax: 65536, disparityMode: 0, disparityShift: 0
# Auto Exposure Control:
#  Mean Intensity Set Point: 1536
# Census:
#  uDiameter: 9, vDiameter: 9
# Depth Control Min Values:
#   minusDecrement: 0, deepSeaMedianThreshold: 0, scoreThreshA: 0, scoreThreshB: 0, textureDifferenceThreshold: 0, textureCountThreshold: 0, deepSeaSecondPeakThreshold: 0, deepSeaNeighborThreshold: 0, lrAgreeThreshold: 0
# Depth Control Max Values:
#   minusDecrement: 255, deepSeaMedianThreshold: 1023, scoreThreshA: 1023, scoreThreshB: 4095, textureDifferenceThreshold: 4095, textureCountThreshold: 1023, deepSeaSecondPeakThreshold: 1023, deepSeaNeighborThreshold: 1023, lrAgreeThreshold: 2047
# After Setting new value, Depth Control:
#  minusDecrement: 10, deepSeaMedianThreshold: 500, scoreThreshA: 511, scoreThreshB: 2047, textureDifferenceThreshold: 0, textureCountThreshold: 0, deepSeaSecondPeakThreshold: 325, deepSeaNeighborThreshold: 7, lrAgreeThreshold: 24
# Controls as JSON:
#  {
#     "aux-param-autoexposure-setpoint": "1536",
#     "aux-param-colorcorrection1": "0.298828",
#     "aux-param-colorcorrection10": "-0",
#     "aux-param-colorcorrection11": "-0",
#     "aux-param-colorcorrection12": "-0",
#     "aux-param-colorcorrection2": "0.293945",
#     "aux-param-colorcorrection3": "0.293945",
#     "aux-param-colorcorrection4": "0.114258",
#     "aux-param-colorcorrection5": "-0",
#     "aux-param-colorcorrection6": "-0",
#     "aux-param-colorcorrection7": "-0",
#     "aux-param-colorcorrection8": "-0",
#     "aux-param-colorcorrection9": "-0",
#     "aux-param-depthclampmax": "65536",
#     "aux-param-depthclampmin": "0",
#     "aux-param-disparityshift": "0",
#     "controls-autoexposure-auto": "True",
#     "controls-autoexposure-manual": "8500",
#     "controls-color-autoexposure-auto": "True",
#     "controls-color-autoexposure-manual": "166",
#     "controls-color-backlight-compensation": "0",
#     "controls-color-brightness": "0",
#     "controls-color-contrast": "50",
#     "controls-color-gain": "64",
#     "controls-color-gamma": "300",
#     "controls-color-hue": "0",
#     "controls-color-power-line-frequency": "3",
#     "controls-color-saturation": "64",
#     "controls-color-sharpness": "50",
#     "controls-color-white-balance-auto": "True",
#     "controls-color-white-balance-manual": "4600",
#     "controls-depth-gain": "16",
#     "controls-laserpower": "150",
#     "controls-laserstate": "on",
#     "ignoreSAD": "0",
#     "param-amplitude-factor": "0",
#     "param-autoexposure-setpoint": "1536",
#     "param-censusenablereg-udiameter": "9",
#     "param-censusenablereg-vdiameter": "9",
#     "param-censususize": "9",
#     "param-censusvsize": "9",
#     "param-depthclampmax": "65536",
#     "param-depthclampmin": "0",
#     "param-depthunits": "1000",
#     "param-disableraucolor": "0",
#     "param-disablesadcolor": "0",
#     "param-disablesadnormalize": "0",
#     "param-disablesloleftcolor": "0",
#     "param-disableslorightcolor": "0",
#     "param-disparitymode": "0",
#     "param-disparityshift": "0",
#     "param-lambdaad": "800",
#     "param-lambdacensus": "26",
#     "param-leftrightthreshold": "24",
#     "param-maxscorethreshb": "2047",
#     "param-medianthreshold": "500",
#     "param-minscorethresha": "511",
#     "param-neighborthresh": "7",
#     "param-raumine": "1",
#     "param-rauminn": "1",
#     "param-rauminnssum": "3",
#     "param-raumins": "1",
#     "param-rauminw": "1",
#     "param-rauminwesum": "3",
#     "param-regioncolorthresholdb": "0.0499022",
#     "param-regioncolorthresholdg": "0.0499022",
#     "param-regioncolorthresholdr": "0.0499022",
#     "param-regionshrinku": "3",
#     "param-regionshrinkv": "1",
#     "param-robbinsmonrodecrement": "10",
#     "param-robbinsmonroincrement": "10",
#     "param-rsmdiffthreshold": "4",
#     "param-rsmrauslodiffthreshold": "1",
#     "param-rsmremovethreshold": "0.375",
#     "param-scanlineedgetaub": "72",
#     "param-scanlineedgetaug": "72",
#     "param-scanlineedgetaur": "72",
#     "param-scanlinep1": "60",
#     "param-scanlinep1onediscon": "105",
#     "param-scanlinep1twodiscon": "70",
#     "param-scanlinep2": "342",
#     "param-scanlinep2onediscon": "190",
#     "param-scanlinep2twodiscon": "130",
#     "param-secondpeakdelta": "325",
#     "param-texturecountthresh": "0",
#     "param-texturedifferencethresh": "0",
#     "param-usersm": "1",
#     "param-zunits": "1000"
# }

# %%
#####################################################
##               Read bag from file                ##
#####################################################


# First import library
import pyrealsense2 as rs
# Import Numpy for easy array manipulation
import numpy as np
# Import OpenCV for easy image rendering
import cv2
# Import argparse for command-line options
import argparse
# Import os.path for file path manipulation
import os.path

# Create object for parsing command-line options
parser = argparse.ArgumentParser(description="Read recorded bag file and display depth stream in jet colormap.\
                                Remember to change the stream fps and format to match the recorded.")
# Add argument which takes path to a bag file as an input
parser.add_argument("-i", "--input", type=str, help="Path to the bag file")
# Parse the command line arguments to an object
args = parser.parse_args()
# Safety if no parameter have been given
if not args.input:
    print("No input paramater have been given.")
    print("For help type --help")
    exit()
# Check if the given file have bag extension
if os.path.splitext(args.input)[1] != ".bag":
    print("The given file is not of correct file format.")
    print("Only .bag files are accepted")
    exit()
try:
    # Create pipeline
    pipeline = rs.pipeline()

    # Create a config object
    config = rs.config()

    # Tell config that we will use a recorded device from file to be used by the pipeline through playback.
    rs.config.enable_device_from_file(config, args.input)

    # Configure the pipeline to stream the depth stream
    # Change this parameters according to the recorded bag file resolution
    config.enable_stream(rs.stream.depth, rs.format.z16, 30)

    # Start streaming from file
    pipeline.start(config)

    # Create opencv window to render image in
    cv2.namedWindow("Depth Stream", cv2.WINDOW_AUTOSIZE)
    
    # Create colorizer object
    colorizer = rs.colorizer()

    # Streaming loop
    while True:
        # Get frameset of depth
        frames = pipeline.wait_for_frames()

        # Get depth frame
        depth_frame = frames.get_depth_frame()

        # Colorize depth frame to jet colormap
        depth_color_frame = colorizer.colorize(depth_frame)

        # Convert depth_frame to numpy array to render image in opencv
        depth_color_image = np.asanyarray(depth_color_frame.get_data())

        # Render image in opencv window
        cv2.imshow("Depth Stream", depth_color_image)
        key = cv2.waitKey(1)
        # if pressed escape exit program
        if key == 27:
            cv2.destroyAllWindows()
            break

finally:
    pass
# Out:
# usage: ipykernel_launcher.py [-h] [-i INPUT]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/piai/.local/share/jupyter/runtime/kernel-87e3620f-260d-4946-b427-b9a374cb8e8b.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/piai/anaconda3/envs/AIBD/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#####################################################
##                  Export to PLY                  ##
#####################################################

# First import the library
import pyrealsense2 as rs


# Declare pointcloud object, for calculating pointclouds and texture mappings
pc = rs.pointcloud()
# We want the points object to be persistent so we can display the last cloud when a frame drops
points = rs.points()

# Declare RealSense pipeline, encapsulating the actual device and sensors
pipe = rs.pipeline()
config = rs.config()
# Enable depth stream
config.enable_stream(rs.stream.depth)

# Start streaming with chosen configuration
pipe.start(config)

# We'll use the colorizer to generate texture for our PLY
# (alternatively, texture can be obtained from color or infrared stream)
colorizer = rs.colorizer()

try:
    # Wait for the next set of frames from the camera
    frames = pipe.wait_for_frames()
    colorized = colorizer.process(frames)

    # Create save_to_ply object
    ply = rs.save_to_ply("1.ply")

    # Set options to the desired values
    # In this example we'll generate a textual PLY with normals (mesh is already created by default)
    ply.set_option(rs.save_to_ply.option_ply_binary, False)
    ply.set_option(rs.save_to_ply.option_ply_normals, True)

    print("Saving to 1.ply...")
    # Apply the processing block to the frameset which contains the depth frame and the texture
    ply.process(colorized)
    print("Done")
finally:
    pipe.stop()
# Out:
# Saving to 1.ply...
# Done

# %%
# Out:
# 1 devices have been found

# %% [markdown]
# ---

# %%
# Initialize Camera Intel Realsense
dc = DepthCamera()

ret, depth_frame, color_frame = dc.get_frame()

# %%
# Show distance for a specific point
# centroid -> circle이.....
# 맞나..
#

point = (400,300)
cv2.circle(color_frame, point, 4, (0, 0, 255))
distance = depth_frame[point[1], point[0]]
cv2.putText(color_frame, "{}mm".format(distance), (point[0], point[1] - 20), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 0), 2)
# Out:
# array([[[31, 44, 18],
#         [27, 40, 14],
#         [24, 36, 12],
#         ...,
#         [48, 57, 20],
#         [46, 56, 21],
#         [49, 59, 24]],
#
#        [[29, 44, 18],
#         [25, 40, 14],
#         [22, 36, 12],
#         ...,
#         [45, 56, 19],
#         [46, 56, 21],
#         [48, 58, 23]],
#
#        [[32, 47, 21],
#         [26, 41, 15],
#         [24, 39, 13],
#         ...,
#         [45, 57, 22],
#         [47, 57, 22],
#         [47, 57, 22]],
#
#        ...,
#
#        [[ 0,  7,  0],
#         [ 1,  8,  0],
#         [ 1,  8,  0],
#         ...,
#         [ 1,  7,  0],
#         [ 1,  7,  0],
#         [ 1,  7,  0]],
#
#        [[ 0,  6,  0],
#         [ 2,  8,  1],
#         [ 2,  8,  1],
#         ...,
#         [ 1,  7,  0],
#         [ 4,  6,  0],
#         [ 3,  5,  0]],
#
#        [[ 1,  7,  0],
#         [ 1,  7,  0],
#         [ 0,  5,  1],
#         ...,
#         [ 0,  6,  0],
#         [ 3,  5,  0],
#         [ 3,  5,  0]]], dtype=uint8)

# %%
def show_distance(event, x, y, args, params):
    global point
    point = (x, y)
# Create mouse event
cv2.namedWindow("Color frame")
cv2.setMouseCallback("Color frame", show_distance)

# %%
# Create a context object. This object owns the handles to all connected realsense devices
pipeline = rs.pipeline()
pipeline.start()

try:
    while True:
        # Create a pipeline object. This object configures the streaming camera and owns it's handle
        frames = pipeline.wait_for_frames()
        depth = frames.get_depth_frame()
        if not depth: continue

        # Print a simple text-based representation of the image, by breaking it into 10x20 pixel regions and approximating the coverage of pixels within one meter
        coverage = [0]*64
        for y in xrange(480):
            for x in xrange(640):
                dist = depth.get_distance(x, y)
                if 0 < dist and dist < 1:
                    coverage[x/10] += 1

            if y%20 is 19:
                line = ""
                for c in coverage:
                    line += " .:nhBXWW"[c/25]
                coverage = [0]*64
                print(line)

finally:
    pipeline.stop()
# Out:
# <>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-f079cfd08a87> in <module>
#       1 # Create a context object. This object owns the handles to all connected realsense devices
#       2 pipeline = rs.pipeline()
# ----> 3 pipeline.start()
#       4
#       5 try:
#
# RuntimeError: xioctl(VIDIOC_S_FMT) failed Last Error: Device or resource busy

# %%
depth = frames.get_depth_frame()
depth_data = depth.as_frame().get_data()
np_image = np.asanyarray(depth_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e0d645ab9649> in <module>
# ----> 1 depth = frames.get_depth_frame()
#       2 depth_data = depth.as_frame().get_data()
#       3 np_image = np.asanyarray(depth_data)
#
# NameError: name 'frames' is not defined
